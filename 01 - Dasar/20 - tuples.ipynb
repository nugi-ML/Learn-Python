# %%
tup = ()
print(tup)

# Using string
tup = ('Python', 'menyenangkan')
print(tup)

# Using list
li = [1,2,3,4,5,6]
print(tuple(li))

# Using Built-in Function
tup = tuple('Python')
print(tup)
# Out:
# ()
# ('Python', 'menyenangkan')
# (1, 2, 3, 4, 5, 6)
# ('P', 'y', 't', 'h', 'o', 'n')
