# %% [markdown]
# ### Dalam Fungsi

# %%
def fun():
    pass

fun()

# %% [markdown]
# ### Dalam Percabangan

# %%
x = 10

if x > 5:
    pass
else:
    print("x sama besar dan kurang dari 5")

# %% [markdown]
# ### Dalam Perluangan

# %%
for i in range(5):
    if i ==3:
        pass
    else:
        print(i)
# Out:
# 0
# 1
# 2
# 4

# %% [markdown]
# ### Dalam Kelas

# %%
class EmptyClass:
    pass

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        pass

p = Person("Nugi", 21)
